# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisAngelOlveraOlvera/Hands-On-Data-Analysis-with-Pandas-Second-Edition/blob/main/Chapter_3_Data_Wrangling_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Install wget (if not already installed)
# !apt install wget

# Download the file using wget
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/wide_data.csv

# Import pandas library
import pandas as pd

# Read the downloaded file into a DataFrame
wide_df = pd.read_csv('wide_data.csv')

# Now you can work with the DataFrame as usual
print(wide_df.head())  # View the first few rows
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# --2024-06-19 01:52:51--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/wide_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 794 [text/plain]
# Saving to: ‘wide_data.csv’
#
# wide_data.csv       100%[===================>]     794  --.-KB/s    in 0s
#
# 2024-06-19 01:52:51 (27.0 MB/s) - ‘wide_data.csv’ saved [794/794]
#
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# ...

# %%
long_df = pd.read_csv("wide_data.csv", parse_dates=["date"])
long_df
# Out:
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# 3  2018-10-04  22.8  11.7  11.7
# 4  2018-10-05  23.3  11.7  18.9
# 5  2018-10-06  20.0  13.3  16.1
# 6  2018-10-07  20.0  16.1  20.0
# 7  2018-10-08  26.7  17.8  17.8
# 8  2018-10-09  18.9  17.2  17.8
# 9  2018-10-10  24.4  17.2  18.3
# 10 2018-10-11  26.1  17.8  21.7
# 11 2018-10-12  22.8  14.4  15.6
# 12 2018-10-13  15.6   7.2   8.3
# 13 2018-10-14  13.3   5.6   6.7
# 14 2018-10-15  13.3   6.7  10.0
# 15 2018-10-16  18.9   7.8   7.8
# 16 2018-10-17  13.3   3.3   5.0
# 17 2018-10-18  16.1   4.4   5.0
# 18 2018-10-19  10.0  -1.1   0.0
# 19 2018-10-20  15.0  -0.6  10.6
# 20 2018-10-21  16.7   7.8   7.8
# 21 2018-10-22   7.8  -1.1  -1.1
# 22 2018-10-23  15.6  -1.1  10.0
# 23 2018-10-24  16.7   4.4   6.7
# 24 2018-10-25  11.7   2.8   2.8
# 25 2018-10-26   9.4  -0.6  -0.6
# 26 2018-10-27   8.9  -0.6   6.1
# 27 2018-10-28   8.3   5.0   7.2
# ...

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/long_data.csv

import pandas as pd

long_df = pd.read_csv("long_data.csv", usecols=[ "date","datatype", "value"], parse_dates=["date"])
print(long_df)  # Mostrar el DataFrame
# Out:
# --2024-06-19 01:52:52--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/long_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5494 (5.4K) [text/plain]
# Saving to: ‘long_data.csv’
#
# long_data.csv       100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2024-06-19 01:52:52 (29.5 MB/s) - ‘long_data.csv’ saved [5494/5494]
#
#    datatype       date  value
# 0      TMAX 2018-10-01   21.1
# 1      TMIN 2018-10-01    8.9
# 2      TOBS 2018-10-01   13.9
# 3      TMAX 2018-10-02   23.9
# 4      TMIN 2018-10-02   13.9
# ..      ...        ...    ...
# 88     TMIN 2018-10-30    2.2
# 89     TOBS 2018-10-30    5.0
# 90     TMAX 2018-10-31   12.2
# 91     TMIN 2018-10-31    0.0
# ...

# %%
wide_df.head(6)
# Out:
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# 3  2018-10-04  22.8  11.7  11.7
# 4  2018-10-05  23.3  11.7  18.9
# 5  2018-10-06  20.0  13.3  16.1

# %%
wide_df.describe(include='all')
# Out:
#               date       TMAX       TMIN       TOBS
# count           31  31.000000  31.000000  31.000000
# unique          31        NaN        NaN        NaN
# top     2018-10-01        NaN        NaN        NaN
# freq             1        NaN        NaN        NaN
# mean           NaN  16.829032   7.561290  10.022581
# std            NaN   5.714962   6.513252   6.596550
# min            NaN   7.800000  -1.100000  -1.100000
# 25%            NaN  12.750000   2.500000   5.550000
# 50%            NaN  16.100000   6.700000   8.300000
# 75%            NaN  21.950000  13.600000  16.100000
# max            NaN  26.700000  17.800000  21.700000

# %%
wide_df.plot(x="date", y = ["TMAX", "TMIN", "TOBS"], figsize=(15,5), title="Temperature in NY 2018").set_ylabel("T in Celsius")
# Out:
# Text(0, 0.5, 'T in Celsius')

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(15,5)}, style="white")
ax = sns.lineplot(data=long_df, x="date", y="value", hue="datatype")
ax.set_title("Temperature in NY 2018")
ax.set_ylabel("T in Celsius")
# Out:
# Text(0, 0.5, 'T in Celsius')

# %%
sns.set(rc={"figure.figsize": (20,10)}, style="white", font_scale=2)
g = sns.FacetGrid(long_df, col="datatype", height=10)
g = g.map(plt.plot, "date", "value")
g.set_titles(size=25)
g.set_xticklabels(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import requests

def make_request(endpoint, payload=None):
  """
  Make a request to the API and return the response.
  """
  return requests.get('https://www.ncdc.noaa.gov/cdo-web/'f'api/v2/{endpoint}',headers={'token': "PPyhShWdKadMiUVHWjLLLuKLZhVCDreP"},params=payload)

response = make_request("datasets", {"startdate" : "2018-01-01"})

print(response.status_code)

response.ok
# Out:
# 200
# True

# %%
"we have our response, we can use the json() method to get the payload. Then, we can use dictionary methods to determine which part we want to look at:"

payload =  response.json()
payload.keys()
# Out:
# dict_keys(['metadata', 'results'])

# %%
payload["metadata"]
# Out:
# {'resultset': {'offset': 1, 'count': 11, 'limit': 25}}

# %%
payload["results"][0].keys()
# Out:
# dict_keys(['uid', 'mindate', 'maxdate', 'name', 'datacoverage', 'id'])

# %%
[(data["id"], data["name"]) for data in payload["results"]]
# Out:
# [('GHCND', 'Daily Summaries'),
#  ('GSOM', 'Global Summary of the Month'),
#  ('GSOY', 'Global Summary of the Year'),
#  ('NEXRAD2', 'Weather Radar (Level II)'),
#  ('NEXRAD3', 'Weather Radar (Level III)'),
#  ('NORMAL_ANN', 'Normals Annual/Seasonal'),
#  ('NORMAL_DLY', 'Normals Daily'),
#  ('NORMAL_HLY', 'Normals Hourly'),
#  ('NORMAL_MLY', 'Normals Monthly'),
#  ('PRECIP_15', 'Precipitation 15 Minute'),
#  ('PRECIP_HLY', 'Precipitation Hourly')]

# %%
response = make_request("datacategories", payload={"datasetid": "GHCND"})
response.status_code
# Out:
# 200

# %%
payload =  response.json()["results"]
payload
# Out:
# [{'name': 'Evaporation', 'id': 'EVAP'},
#  {'name': 'Land', 'id': 'LAND'},
#  {'name': 'Precipitation', 'id': 'PRCP'},
#  {'name': 'Sky cover & clouds', 'id': 'SKY'},
#  {'name': 'Sunshine', 'id': 'SUN'},
#  {'name': 'Air Temperature', 'id': 'TEMP'},
#  {'name': 'Water', 'id': 'WATER'},
#  {'name': 'Wind', 'id': 'WIND'},
#  {'name': 'Weather Type', 'id': 'WXTYPE'}]

# %%
response = make_request("datatypes", payload={"datacategoryid": "TEMP", "limit": 100})

response.status_code
# Out:
# 200

# %%
[(datatype[0], datatype[1]) for datatype in [("CDSD", "Cooling degree days season to date"), ("TAVG", "Average Temperature"),('TMAX', 'Maximum temperature'),('TMIN', 'Minimum temperature'),('TOBS', 'Temperature at the time of observation')]]
# Out:
# [('CDSD', 'Cooling degree days season to date'),
#  ('TAVG', 'Average Temperature'),
#  ('TMAX', 'Maximum temperature'),
#  ('TMIN', 'Minimum temperature'),
#  ('TOBS', 'Temperature at the time of observation')]

# %%
response = make_request("locationcategories", payload={"datasetid": "GHCND"})
response.status_code
# Out:
# 200

# %%
import pprint
pprint.pprint(response.json())
# Out:
# {'metadata': {'resultset': {'count': 12, 'limit': 25, 'offset': 1}},
#  'results': [{'id': 'CITY', 'name': 'City'},
#              {'id': 'CLIM_DIV', 'name': 'Climate Division'},
#              {'id': 'CLIM_REG', 'name': 'Climate Region'},
#              {'id': 'CNTRY', 'name': 'Country'},
#              {'id': 'CNTY', 'name': 'County'},
#              {'id': 'HYD_ACC', 'name': 'Hydrologic Accounting Unit'},
#              {'id': 'HYD_CAT', 'name': 'Hydrologic Cataloging Unit'},
#              {'id': 'HYD_REG', 'name': 'Hydrologic Region'},
#              {'id': 'HYD_SUB', 'name': 'Hydrologic Subregion'},
#              {'id': 'ST', 'name': 'State'},
#              {'id': 'US_TERR', 'name': 'US Territory'},
#              {'id': 'ZIP', 'name': 'Zip Code'}]}

# %%
from logging import currentframe

def get_item(name, what, endpoint, start=1, end=None):
    """
    Grab the JSON payload using binary search.

    Parameters:
    - name: The item to look for.
    - what: Dictionary specifying what item `name` is.
    - endpoint: Where to look for the item.
    - start: The position to start at. We don't need
      to touch this, but the function will manipulate
      this with recursion.
    - end: The last position of the items. Used to
      find the midpoint, but like `start` this is not
      something we need to worry about.

    Returns: Dictionary of the information for the item
      if found, otherwise an empty dictionary.
    """
    # find the midpoint to cut the data in half each time
    mid = (start + end) // 2 if end is not None else start

    # lowercase the name so this is not case-sensitive
    name = name.lower()

    # define the payload we will send with each request
    payload = {"datasetid": "GHCND", "sortfield": "name", "offset": mid, "limit": 1}

    # make a request adding additional filters from "what"
    response = make_request(endpoint, {**payload, **what})

    if response.ok:
        payload = response.json()
        # if ok, grab the end index from the response
        # metadata the first time through
        end = end or payload["metadata"]["resultset"]["count"]
        # grab the lowercase version of the current name
        current_name = payload["results"][0]["name"].lower()
        # if what we are searching for is in the current
        # name, we have found our item
        if name in current_name:
            return payload["results"][0]
        else:
            if start >= end:
                return {}
            elif name < current_name:
                return get_item(name, what, endpoint, start, mid - 1)
            elif name > current_name:
                return get_item(name, what, endpoint, mid + 1, end)
    else:
        print(f"Error: {response.status_code}")
        return {}

nyc = get_item("New York", {"locationcategoryid": "CITY"}, "locations")

# %%
nyc
# Out:
# {'mindate': '1869-01-01',
#  'maxdate': '2024-06-17',
#  'name': 'New York, NY US',
#  'datacoverage': 1,
#  'id': 'CITY:US360019'}

# %%
central_park = get_item('NY City Central Park', {'locationid': nyc['id']}, 'stations' )

# %%
central_park
# Out:
# {'elevation': 42.7,
#  'mindate': '1869-01-01',
#  'maxdate': '2024-06-16',
#  'latitude': 40.77898,
#  'name': 'NY CITY CENTRAL PARK, NY US',
#  'datacoverage': 1,
#  'id': 'GHCND:USW00094728',
#  'elevationUnit': 'METERS',
#  'longitude': -73.96925}

# %%
response = make_request('data',{'datasetid': 'GHCND','stationid': central_park['id'],'locationid': nyc['id'],'startdate': '2018-10-01','enddate': '2018-10-31','datatypeid': ['TAVG', 'TMAX', 'TMIN'], 'units': 'metric','limit': 1000})
response.status_code
# Out:
# 200

# %%
import pandas as pd
df = pd.DataFrame(response.json()['results'])
df.head()
# Out:
#                   date datatype            station attributes  value
# 0  2018-10-01T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   24.4
# 1  2018-10-01T00:00:00     TMIN  GHCND:USW00094728   ,,W,2400   17.2
# 2  2018-10-02T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   25.0
# 3  2018-10-02T00:00:00     TMIN  GHCND:USW00094728   ,,W,2400   18.3
# 4  2018-10-03T00:00:00     TMAX  GHCND:USW00094728   ,,W,2400   23.3

# %%
df.datatype.unique()
# Out:
# array(['TMAX', 'TMIN'], dtype=object)

# %%
if get_item(
  'NY City Central Park',
  {'locationid': nyc['id'], 'datatypeid': 'TAVG'},
  'stations'):
  print('Found!')
# Out:
# Found!

# %%
# Cleaning data
import pandas as pd

# Corrected URL for raw file on GitHub
csv_url = "https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas/master/ch_03/data/nyc_temperatures.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_url)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   attributes datatype                 date            station  value
# 0      H,,S,     TAVG  2018-10-01T00:00:00  GHCND:USW00014732   21.2
# 1   ,,W,2400     TMAX  2018-10-01T00:00:00  GHCND:USW00014732   25.6
# 2   ,,W,2400     TMIN  2018-10-01T00:00:00  GHCND:USW00014732   18.3
# 3      H,,S,     TAVG  2018-10-02T00:00:00  GHCND:USW00014732   22.7
# 4   ,,W,2400     TMAX  2018-10-02T00:00:00  GHCND:USW00014732   26.1

# %%
# renaming columns
df.columns
# Out:
# Index(['attributes', 'datatype', 'date', 'station', 'value'], dtype='object')

# %%
df.rename(columns={"value": "temp_C", "attributes": "flags"}, inplace=True)
print(df)
# Out:
#        flags datatype                 date            station  temp_C
# 0      H,,S,     TAVG  2018-10-01T00:00:00  GHCND:USW00014732    21.2
# 1   ,,W,2400     TMAX  2018-10-01T00:00:00  GHCND:USW00014732    25.6
# 2   ,,W,2400     TMIN  2018-10-01T00:00:00  GHCND:USW00014732    18.3
# 3      H,,S,     TAVG  2018-10-02T00:00:00  GHCND:USW00014732    22.7
# 4   ,,W,2400     TMAX  2018-10-02T00:00:00  GHCND:USW00014732    26.1
# ..       ...      ...                  ...                ...     ...
# 88  ,,W,2400     TMAX  2018-10-30T00:00:00  GHCND:USW00014732    13.9
# 89  ,,W,2400     TMIN  2018-10-30T00:00:00  GHCND:USW00014732     7.2
# 90     H,,S,     TAVG  2018-10-31T00:00:00  GHCND:USW00014732    12.6
# 91  ,,W,2400     TMAX  2018-10-31T00:00:00  GHCND:USW00014732    17.8
# 92  ,,W,2400     TMIN  2018-10-31T00:00:00  GHCND:USW00014732     7.2
#
# [93 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['flags', 'datatype', 'date', 'station', 'temp_C'], dtype='object')

# %%
df.rename(str.upper, axis="columns").columns
# Out:
# Index(['FLAGS', 'DATATYPE', 'DATE', 'STATION', 'TEMP_C'], dtype='object')

# %%
df.dtypes
# Out:
# flags        object
# datatype     object
# date         object
# station      object
# temp_C      float64
# dtype: object

# %%
df.loc[:,'date'] = pd.to_datetime(df.date)
df.dtypes
# Out:
# flags        object
# datatype     object
# date         object
# station      object
# temp_C      float64
# dtype: object

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Describe the 'date' column (it will now be treated as datetime)
date_stats = df['date'].describe()

# Print or use the 'date_stats' variable for further analysis
print(date_stats)
# Out:
# count                     93
# mean     2018-10-16 00:00:00
# min      2018-10-01 00:00:00
# 25%      2018-10-08 00:00:00
# 50%      2018-10-16 00:00:00
# 75%      2018-10-24 00:00:00
# max      2018-10-31 00:00:00
# Name: date, dtype: object

# %%
pd.date_range('2018-01-01', '2018-01-10')
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2018-01-01', periods=2, freq="D").tz_localize('EST')
# Out:
# DatetimeIndex(['2018-01-01 00:00:00-05:00', '2018-01-02 00:00:00-05:00'], dtype='datetime64[ns, EST]', freq=None)

# %%
eastern = df = pd.read_csv(csv_url, index_col='date', parse_dates=True).tz_localize('EST')
eastern.head()
# Out:
#                           attributes datatype            station  value
# date
# 2018-10-01 00:00:00-05:00      H,,S,     TAVG  GHCND:USW00014732   21.2
# 2018-10-01 00:00:00-05:00   ,,W,2400     TMAX  GHCND:USW00014732   25.6
# 2018-10-01 00:00:00-05:00   ,,W,2400     TMIN  GHCND:USW00014732   18.3
# 2018-10-02 00:00:00-05:00      H,,S,     TAVG  GHCND:USW00014732   22.7
# 2018-10-02 00:00:00-05:00   ,,W,2400     TMAX  GHCND:USW00014732   26.1

# %%
eastern.tz_convert('UTC').head()
# Out:
#                           attributes datatype            station  value
# date
# 2018-10-01 05:00:00+00:00      H,,S,     TAVG  GHCND:USW00014732   21.2
# 2018-10-01 05:00:00+00:00   ,,W,2400     TMAX  GHCND:USW00014732   25.6
# 2018-10-01 05:00:00+00:00   ,,W,2400     TMIN  GHCND:USW00014732   18.3
# 2018-10-02 05:00:00+00:00      H,,S,     TAVG  GHCND:USW00014732   22.7
# 2018-10-02 05:00:00+00:00   ,,W,2400     TMAX  GHCND:USW00014732   26.1

# %%
df = pd.read_csv(csv_url).rename(columns={"value": "temp_C", "attributes": "flags"})

new_df = df.assign(date=pd.to_datetime(df.date), temp_F=(df.temp_C*9/5)+32)
new_df.head()
# Out:
#       flags datatype       date            station  temp_C  temp_F
# 0     H,,S,     TAVG 2018-10-01  GHCND:USW00014732    21.2   70.16
# 1  ,,W,2400     TMAX 2018-10-01  GHCND:USW00014732    25.6   78.08
# 2  ,,W,2400     TMIN 2018-10-01  GHCND:USW00014732    18.3   64.94
# 3     H,,S,     TAVG 2018-10-02  GHCND:USW00014732    22.7   72.86
# 4  ,,W,2400     TMAX 2018-10-02  GHCND:USW00014732    26.1   78.98

# %%
df = df.assign(
    date = lambda x: pd.to_datetime(x.date),
    temp_C_whole = lambda x: x.temp_C.astype("int"),
    temp_F=lambda x: (x.temp_C * 9/5) + 32,
    temp_F_whole = lambda x: x.temp_F.astype("int")
)
df.head()
# Out:
#       flags datatype       date            station  temp_C  temp_C_whole  \
# 0     H,,S,     TAVG 2018-10-01  GHCND:USW00014732    21.2            21
# 1  ,,W,2400     TMAX 2018-10-01  GHCND:USW00014732    25.6            25
# 2  ,,W,2400     TMIN 2018-10-01  GHCND:USW00014732    18.3            18
# 3     H,,S,     TAVG 2018-10-02  GHCND:USW00014732    22.7            22
# 4  ,,W,2400     TMAX 2018-10-02  GHCND:USW00014732    26.1            26
#
#    temp_F  temp_F_whole
# 0   70.16            70
# 1   78.08            78
# 2   64.94            64
# 3   72.86            72
# 4   78.98            78

# %%
from typing_extensions import dataclass_transform
df_with_categories = df.assign( statuin = df.station.astype("category"), datatype = df.datatype.astype("category"))
df_with_categories.dtypes
# Out:
# flags                   object
# datatype              category
# date            datetime64[ns]
# station                 object
# temp_C                 float64
# temp_C_whole             int64
# temp_F                 float64
# temp_F_whole             int64
# statuin               category
# dtype: object

# %%
df_with_categories.describe(include='category')
# Out:
#        datatype            statuin
# count        93                 93
# unique        3                  1
# top        TAVG  GHCND:USW00014732
# freq         31                 93

# %%
pd.Categorical( ['med', 'med', 'low', 'high'],categories=['low', 'med', 'high'],ordered=True)
# Out:
# ['med', 'med', 'low', 'high']
# Categories (3, object): ['low' < 'med' < 'high']

# %%
df[df.datatype == "TMAX"].sort_values(by="temp_C", ascending=False).head(10)
# Out:
#        flags datatype       date            station  temp_C  temp_C_whole  \
# 19  ,,W,2400     TMAX 2018-10-07  GHCND:USW00014732    27.8            27
# 28  ,,W,2400     TMAX 2018-10-10  GHCND:USW00014732    27.8            27
# 31  ,,W,2400     TMAX 2018-10-11  GHCND:USW00014732    26.7            26
# 10  ,,W,2400     TMAX 2018-10-04  GHCND:USW00014732    26.1            26
# 4   ,,W,2400     TMAX 2018-10-02  GHCND:USW00014732    26.1            26
# 1   ,,W,2400     TMAX 2018-10-01  GHCND:USW00014732    25.6            25
# 25  ,,W,2400     TMAX 2018-10-09  GHCND:USW00014732    25.6            25
# 7   ,,W,2400     TMAX 2018-10-03  GHCND:USW00014732    25.0            25
# 13  ,,W,2400     TMAX 2018-10-05  GHCND:USW00014732    22.8            22
# 22  ,,W,2400     TMAX 2018-10-08  GHCND:USW00014732    22.8            22
#
#     temp_F  temp_F_whole
# 19   82.04            82
# 28   82.04            82
# 31   80.06            80
# 10   78.98            78
# ...

# %%
df[df.datatype == "TMAX"].sort_values(by="temp_C", ascending=True).head(10)
# Out:
#        flags datatype       date            station  temp_C  temp_C_whole  \
# 76  ,,W,2400     TMAX 2018-10-26  GHCND:USW00014732    10.0            10
# 73  ,,W,2400     TMAX 2018-10-25  GHCND:USW00014732    11.1            11
# 64  ,,W,2400     TMAX 2018-10-22  GHCND:USW00014732    11.1            11
# 79  ,,W,2400     TMAX 2018-10-27  GHCND:USW00014732    11.7            11
# 52  ,,W,2400     TMAX 2018-10-18  GHCND:USW00014732    11.7            11
# 82  ,,W,2400     TMAX 2018-10-28  GHCND:USW00014732    12.2            12
# 61  ,,W,2400     TMAX 2018-10-21  GHCND:USW00014732    12.2            12
# 70  ,,W,2400     TMAX 2018-10-24  GHCND:USW00014732    13.3            13
# 88  ,,W,2400     TMAX 2018-10-30  GHCND:USW00014732    13.9            13
# 85  ,,W,2400     TMAX 2018-10-29  GHCND:USW00014732    14.4            14
#
#     temp_F  temp_F_whole
# 76   50.00            50
# 73   51.98            51
# 64   51.98            51
# 79   53.06            53
# ...

# %%
# Filtra el DataFrame por filas donde el tipo de dato es "TMAX" y ordena por "temp_C" descendente y "date" ascendente
df_filtered_sorted = df[df['datatype'] == "TMAX"].sort_values(by=["temp_C", "date"], ascending=[False, True])

# Muestra las primeras 10 filas del DataFrame filtrado y ordenado
df_filtered_sorted.head(10)
# Out:
#        flags datatype       date            station  temp_C  temp_C_whole  \
# 19  ,,W,2400     TMAX 2018-10-07  GHCND:USW00014732    27.8            27
# 28  ,,W,2400     TMAX 2018-10-10  GHCND:USW00014732    27.8            27
# 31  ,,W,2400     TMAX 2018-10-11  GHCND:USW00014732    26.7            26
# 4   ,,W,2400     TMAX 2018-10-02  GHCND:USW00014732    26.1            26
# 10  ,,W,2400     TMAX 2018-10-04  GHCND:USW00014732    26.1            26
# 1   ,,W,2400     TMAX 2018-10-01  GHCND:USW00014732    25.6            25
# 25  ,,W,2400     TMAX 2018-10-09  GHCND:USW00014732    25.6            25
# 7   ,,W,2400     TMAX 2018-10-03  GHCND:USW00014732    25.0            25
# 13  ,,W,2400     TMAX 2018-10-05  GHCND:USW00014732    22.8            22
# 22  ,,W,2400     TMAX 2018-10-08  GHCND:USW00014732    22.8            22
#
#     temp_F  temp_F_whole
# 19   82.04            82
# 28   82.04            82
# 31   80.06            80
# 4    78.98            78
# ...

# %%
df[df.datatype == 'TAVG'].nlargest(n=10, columns='temp_C')
# Out:
#     flags datatype       date            station  temp_C  temp_C_whole  \
# 27  H,,S,     TAVG 2018-10-10  GHCND:USW00014732    23.8            23
# 30  H,,S,     TAVG 2018-10-11  GHCND:USW00014732    23.4            23
# 18  H,,S,     TAVG 2018-10-07  GHCND:USW00014732    22.8            22
# 3   H,,S,     TAVG 2018-10-02  GHCND:USW00014732    22.7            22
# 6   H,,S,     TAVG 2018-10-03  GHCND:USW00014732    21.8            21
# 24  H,,S,     TAVG 2018-10-09  GHCND:USW00014732    21.8            21
# 9   H,,S,     TAVG 2018-10-04  GHCND:USW00014732    21.3            21
# 0   H,,S,     TAVG 2018-10-01  GHCND:USW00014732    21.2            21
# 21  H,,S,     TAVG 2018-10-08  GHCND:USW00014732    20.9            20
# 12  H,,S,     TAVG 2018-10-05  GHCND:USW00014732    20.3            20
#
#     temp_F  temp_F_whole
# 27   74.84            74
# 30   74.12            74
# 18   73.04            73
# 3    72.86            72
# 6    71.24            71
# 24   71.24            71
# ...

# %%
df.equals(df.sort_values(by="temp_C"))
# Out:
# False

# %%
df.equals(df.sort_values(by='temp_C').sort_index())
# Out:
# True

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import StrMethodFormatter

bitcoin = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas/master/ch_03/data/bitcoin.csv")
bitcoin.head()
# Out:
#          date     open     high      low    close     volume   market_cap
# 0  2017-01-01   963.66  1003.08   958.70   998.33  147775008  16050407461
# 1  2017-01-02   998.62  1031.39   996.70  1021.75  222184992  16429024775
# 2  2017-01-03  1021.60  1044.08  1021.60  1043.84  185168000  16786368910
# 3  2017-01-04  1044.40  1159.42  1044.40  1154.73  344945984  18571869009
# 4  2017-01-05  1156.73  1191.10   910.42  1013.38  510199008  16300254795

# %%
bitcoin = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas/master/ch_03/data/bitcoin.csv", index_col = "date", parse_dates=True).drop(columns=["market_cap"])
bitcoin.head()
# Out:
#                open     high      low    close     volume
# date
# 2017-01-01   963.66  1003.08   958.70   998.33  147775008
# 2017-01-02   998.62  1031.39   996.70  1021.75  222184992
# 2017-01-03  1021.60  1044.08  1021.60  1043.84  185168000
# 2017-01-04  1044.40  1159.42  1044.40  1154.73  344945984
# 2017-01-05  1156.73  1191.10   910.42  1013.38  510199008

# %%
sp = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/sp500.csv")
sp.head()
# Out:
#          date         high          low         open        close      volume  \
# 0  2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 1  2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2  2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 3  2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 4  2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000
#
#      adj_close
# 0  2257.830078
# 1  2270.750000
# 2  2269.000000
# 3  2276.979980
# 4  2268.899902

# %%
sp = pd.read_csv("https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_03/data/sp500.csv", index_col = "date", parse_dates=True).drop(columns=["adj_close"]) # not using that column
sp.head()
# Out:
#                    high          low         open        close      volume
# date
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000

# %%
sp.head(10).assign(day_of_week = lambda x: x.index.day_name())
# Out:
#                    high          low         open        close      volume  \
# date
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000
# 2017-01-10  2279.270020  2265.270020  2269.719971  2268.899902  3638790000
# 2017-01-11  2275.320068  2260.830078  2268.600098  2275.320068  3620410000
# 2017-01-12  2271.780029  2254.250000  2271.139893  2270.439941  3462130000
# 2017-01-13  2278.679932  2271.510010  2272.739990  2274.639893  3081270000
# 2017-01-17  2272.080078  2262.810059  2269.139893  2267.889893  3584990000
#
#            day_of_week
# date
# 2017-01-03     Tuesday
# 2017-01-04   Wednesday
# 2017-01-05    Thursday
# 2017-01-06      Friday
# ...

# %%
# every day's closing price = S&P 500 close + Bitcoin close
# (same for other metrics)

portfolio = pd.concat([sp, bitcoin], sort = False).groupby(level="date").sum()
portfolio.head()
# Out:
#                    high          low         open        close      volume
# date
# 2017-01-01  1003.080000   958.700000   963.660000   998.330000   147775008
# 2017-01-02  1031.390000   996.700000   998.620000  1021.750000   222184992
# 2017-01-03  3307.959883  3266.729883  3273.170068  3301.670078  3955698000
# 2017-01-04  3432.240068  3306.000098  3306.000098  3425.480000  4109835984
# 2017-01-05  3462.600000  3170.869951  3424.909932  3282.380000  4272019008

# %%
import matplotlib.pyplot as plt # module for plotting
from matplotlib.ticker import StrMethodFormatter # module for formatting numbers

# plot the closing proce from Q4 through Q2 2018
ax = portfolio["2017-Q4": "2018-Q2"].plot(y="close", figsize=(15,5), legend=False, title="Bitcoin + S&P 500 value without accounting " "for different indices")

# %%
# Formatting
# plot the closing proce from Q4 through Q2 2018
ax = portfolio["2017-Q4": "2018-Q2"].plot(y="close", figsize=(15,5), legend=False, title="Bitcoin + S&P 500 value without accounting " "for different indices")
ax.set_ylabel("Price")
ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))

for spine in ["top", "right"]:
    ax.spines[spine].set_visible(False)

# Show the plot
plt.show()

# %%
sp.reindex(bitcoin.index, method="ffill").head(10).assign(day_of_week = lambda x: x.index.day_name())
# Out:
#                    high          low         open        close        volume  \
# date
# 2017-01-01          NaN          NaN          NaN          NaN           NaN
# 2017-01-02          NaN          NaN          NaN          NaN           NaN
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3.770530e+09
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3.764890e+09
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3.761820e+09
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3.339890e+09
# 2017-01-07  2282.100098  2264.060059  2271.139893  2276.979980  3.339890e+09
# 2017-01-08  2282.100098  2264.060059  2271.139893  2276.979980  3.339890e+09
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3.217610e+09
# 2017-01-10  2279.270020  2265.270020  2269.719971  2268.899902  3.638790e+09
#
#            day_of_week
# date
# 2017-01-01      Sunday
# 2017-01-02      Monday
# 2017-01-03     Tuesday
# ...

# %%
import numpy as np

sp_reindexed = sp.reindex(bitcoin.index).assign(
    # Volume is 0 when  the market is closed
    volume=lambda x: x.volume.fillna(0),
    # carry this forward
    close = lambda x:  x.close.fillna(method="ffill"),
    # take the closing price if these aren't available
    open = lambda x: np.where(x.open.isnull(), x.close, x.open),
    high=lambda x: np.where(x.high.isnull(), x.close, x.high),
    low=lambda x: np.where(x.low.isnull(), x.close, x.low))

# %%
sp_reindexed.head(10).assign(day_of_week = lambda x: x.index.day_name())
# Out:
#                    high          low         open        close        volume  \
# date
# 2017-01-01          NaN          NaN          NaN          NaN  0.000000e+00
# 2017-01-02          NaN          NaN          NaN          NaN  0.000000e+00
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3.770530e+09
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3.764890e+09
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3.761820e+09
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3.339890e+09
# 2017-01-07  2276.979980  2276.979980  2276.979980  2276.979980  0.000000e+00
# 2017-01-08  2276.979980  2276.979980  2276.979980  2276.979980  0.000000e+00
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3.217610e+09
# 2017-01-10  2279.270020  2265.270020  2269.719971  2268.899902  3.638790e+09
#
#            day_of_week
# date
# 2017-01-01      Sunday
# 2017-01-02      Monday
# 2017-01-03     Tuesday
# ...

# %%
# every day's closing price = S&P 500 close adjusted for
# market closure + Bitcoin close (same for other metrics)

fixed_portfolio = sp_reindexed + bitcoin

# plot the reindexed portfolio's close (Q4 2017 - Q2 2018)
ax = fixed_portfolio['2017-Q4':'2018-Q2'].plot(y='close', figsize=(15, 5), linewidth=2, label='reindexed portfolio of S&P 500 + Bitcoin', title='Reindexed portfolio vs.' 'portfolio with mismatched indices')

# add line for original  portfolio
portfolio['2017-Q4':'2018-Q2'].plot(y='close', ax=ax, linestyle='--',label='portfolio of S&P 500 + Bitcoin w/o reindexing')

# formatting
ax.set_ylabel('price')
ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
for spine in ['top', 'right']:
  ax.spines[spine].set_visible(False)
# show the plot
plt.show()

# %%
# Ejemplo sencillo de reindex
# formatting
import pandas as pd

data = {'producto': ['Camiseta', 'Zapatilla', 'Camiseta', 'Zapatilla'],
        'mes': ['Enero', 'Enero', 'Febrero', 'Febrero'],
        'ventas': [100, 200, 150, 220]}

df = pd.DataFrame(data)
print(df)
# Out:
#     producto      mes  ventas
# 0   Camiseta    Enero     100
# 1  Zapatilla    Enero     200
# 2   Camiseta  Febrero     150
# 3  Zapatilla  Febrero     220

# %%
nuevo_indice = ['Camiseta_Enero', 'Camiseta_Febrero', 'Zapatilla_Enero', 'Zapatilla_Febrero']
print(nuevo_indice)
# Out:
# ['Camiseta_Enero', 'Camiseta_Febrero', 'Zapatilla_Enero', 'Zapatilla_Febrero']

# %%
df_reindexado = df.reindex(nuevo_indice)
print(df_reindexado)
# Out:
#                   producto  mes  ventas
# Camiseta_Enero         NaN  NaN     NaN
# Camiseta_Febrero       NaN  NaN     NaN
# Zapatilla_Enero        NaN  NaN     NaN
# Zapatilla_Febrero      NaN  NaN     NaN

# %%
import pandas as pd

# Datos de ventas
data = {'producto': ['Camiseta', 'Zapatilla', 'Camiseta', 'Zapatilla'],
        'mes': ['Enero', 'Enero', 'Febrero', 'Febrero'],
        'ventas': [100, 200, 150, 220]}

# Crear DataFrame original
df = pd.DataFrame(data)
print("DataFrame original:")
print(df)

# Crear nueva columna combinada para el índice
df['nuevo_indice'] = df['producto'] + '_' + df['mes']

# Establecer la nueva columna como el índice del DataFrame
df.set_index('nuevo_indice', inplace=True)

# Crear nuevo índice
nuevo_indice = ['Camiseta_Enero', 'Camiseta_Febrero', 'Zapatilla_Enero', 'Zapatilla_Febrero']

# Reindexar el DataFrame
df_reindexado = df.reindex(nuevo_indice)
print("\nDataFrame reindexado:")
print(df_reindexado)
# Out:
# DataFrame original:
#     producto      mes  ventas
# 0   Camiseta    Enero     100
# 1  Zapatilla    Enero     200
# 2   Camiseta  Febrero     150
# 3  Zapatilla  Febrero     220
#
# DataFrame reindexado:
#                     producto      mes  ventas
# nuevo_indice
# Camiseta_Enero      Camiseta    Enero     100
# Camiseta_Febrero    Camiseta  Febrero     150
# Zapatilla_Enero    Zapatilla    Enero     200
# Zapatilla_Febrero  Zapatilla  Febrero     220

# %%
##### RESHAPING DATA PÁGINA 166
